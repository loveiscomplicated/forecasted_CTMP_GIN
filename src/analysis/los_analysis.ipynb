# %%
import os
import pandas as pd
import numpy as np

def make_binary(df):
    df['REASONb'] = np.where(df['REASON'] == 1, 1, 0)
    df = df.drop(['REASON'], axis=1)
    return df

cur_dir = os.getcwd()
data_path = os.path.join(cur_dir, '..', 'data', 'raw', 'missing_corrected.csv')

df = pd.read_csv(data_path)
df_b = make_binary(df)
df_b["REASONb"]
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1394133    0
# 1394134    0
# 1394135    1
# 1394136    0
# 1394137    1
# Name: REASONb, Length: 1394138, dtype: int64

# %%
for i in range(1, 38):
    print(f"\nLOS: {i}")
    print(df_b["REASONb"][df["LOS"] == i].value_counts())
# Out:
# LOS: 1
# REASONb
# 0    139161
# 1     87247
# Name: count, dtype: int64
#
# LOS: 2
# REASONb
# 0    39829
# 1    18533
# Name: count, dtype: int64
#
# LOS: 3
# REASONb
# 0    28805
# 1    20281
# Name: count, dtype: int64
#
# LOS: 4
# REASONb
# 1    24034
# 0    20677
# Name: count, dtype: int64
#
# LOS: 5
# REASONb
# 1    28145
# 0    17072
# Name: count, dtype: int64
#
# LOS: 6
# REASONb
# 1    17705
# 0    14423
# Name: count, dtype: int64
#
# LOS: 7
# REASONb
# 1    16627
# 0    12980
# Name: count, dtype: int64
#
# LOS: 8
# REASONb
# 0    12911
# 1     9281
# Name: count, dtype: int64
#
# LOS: 9
# REASONb
# 0    8650
# 1    6524
# Name: count, dtype: int64
#
# LOS: 10
# REASONb
# 0    7338
# 1    4951
# Name: count, dtype: int64
#
# LOS: 11
# REASONb
# 0    6396
# 1    3767
# Name: count, dtype: int64
#
# LOS: 12
# REASONb
# 0    5725
# 1    3454
# Name: count, dtype: int64
#
# LOS: 13
# REASONb
# 0    6483
# 1    5185
# Name: count, dtype: int64
#
# LOS: 14
# REASONb
# ...

# %%
df["REASON"][df["LOS"] == 2].value_counts()
# Out:
# REASON
# 1    18533
# 2    18054
# 4    17346
# 7     2635
# 3     1507
# 5      261
# 6       26
# Name: count, dtype: int64

# %%
_D = []
_A = []

for col in df.columns:
    if "_D" in col:
        _D.append(col)
    else:
        if "REASONb" == col:
            continue
        _A.append(col)


print(len(_D))
print(_D)
print(len(_A))
# Out:
# 12
# ['SERVICES_D', 'EMPLOY_D', 'LIVARAG_D', 'ARRESTS_D', 'DETNLF_D', 'SUB1_D', 'SUB2_D', 'SUB3_D', 'FREQ1_D', 'FREQ2_D', 'FREQ3_D', 'FREQ_ATND_SELF_HELP_D']
# 64
# False

# %%
raw_path = "/Users/jeong-yunseong/Documents/programming/Phase_2_public/src/data/raw/TEDS_Discharge.csv"
import pandas as pd
rdf = pd.read_csv(raw_path)
rdf.columns
# Out:
# Index(['DISYR', 'CASEID', 'STFIPS', 'EDUC', 'MARSTAT', 'SERVICES', 'DETCRIM',
#        'LOS', 'PSOURCE', 'NOPRIOR', 'ARRESTS', 'EMPLOY', 'METHUSE', 'PSYPROB',
#        'PREG', 'GENDER', 'VET', 'LIVARAG', 'DAYWAIT', 'SERVICES_D', 'REASON',
#        'EMPLOY_D', 'LIVARAG_D', 'ARRESTS_D', 'DSMCRIT', 'AGE', 'RACE',
#        'ETHNIC', 'DETNLF', 'DETNLF_D', 'PRIMINC', 'SUB1', 'SUB2', 'SUB3',
#        'SUB1_D', 'SUB2_D', 'SUB3_D', 'ROUTE1', 'ROUTE2', 'ROUTE3', 'FREQ1',
#        'FREQ2', 'FREQ3', 'FREQ1_D', 'FREQ2_D', 'FREQ3_D', 'FRSTUSE1',
#        'FRSTUSE2', 'FRSTUSE3', 'HLTHINS', 'PRIMPAY', 'FREQ_ATND_SELF_HELP',
#        'FREQ_ATND_SELF_HELP_D', 'ALCFLG', 'COKEFLG', 'MARFLG', 'HERFLG',
#        'METHFLG', 'OPSYNFLG', 'PCPFLG', 'HALLFLG', 'MTHAMFLG', 'AMPHFLG',
#        'STIMFLG', 'BENZFLG', 'TRNQFLG', 'BARBFLG', 'SEDHPFLG', 'INHFLG',
#        'OTCFLG', 'OTHERFLG', 'DIVISION', 'REGION', 'IDU', 'ALCDRUG',
#        'CBSA2020'],
#       dtype='object')

# %%
no_col = ["DISYR", "CASEID", "REASON",]
len(rdf.columns) - 3

_D = []
_A = []
for i in rdf.columns:
    if i in no_col:
        continue
    if "_D" in i:
        _D.append(i)
    else:
        _A.append(i)ㅓ
print(len(_D), _D)
print(len(_A), _A)
# Out:
# 12 ['SERVICES_D', 'EMPLOY_D', 'LIVARAG_D', 'ARRESTS_D', 'DETNLF_D', 'SUB1_D', 'SUB2_D', 'SUB3_D', 'FREQ1_D', 'FREQ2_D', 'FREQ3_D', 'FREQ_ATND_SELF_HELP_D']
# 61 ['STFIPS', 'EDUC', 'MARSTAT', 'SERVICES', 'DETCRIM', 'LOS', 'PSOURCE', 'NOPRIOR', 'ARRESTS', 'EMPLOY', 'METHUSE', 'PSYPROB', 'PREG', 'GENDER', 'VET', 'LIVARAG', 'DAYWAIT', 'DSMCRIT', 'AGE', 'RACE', 'ETHNIC', 'DETNLF', 'PRIMINC', 'SUB1', 'SUB2', 'SUB3', 'ROUTE1', 'ROUTE2', 'ROUTE3', 'FREQ1', 'FREQ2', 'FREQ3', 'FRSTUSE1', 'FRSTUSE2', 'FRSTUSE3', 'HLTHINS', 'PRIMPAY', 'FREQ_ATND_SELF_HELP', 'ALCFLG', 'COKEFLG', 'MARFLG', 'HERFLG', 'METHFLG', 'OPSYNFLG', 'PCPFLG', 'HALLFLG', 'MTHAMFLG', 'AMPHFLG', 'STIMFLG', 'BENZFLG', 'TRNQFLG', 'BARBFLG', 'SEDHPFLG', 'INHFLG', 'OTCFLG', 'OTHERFLG', 'DIVISION', 'REGION', 'IDU', 'ALCDRUG', 'CBSA2020']
